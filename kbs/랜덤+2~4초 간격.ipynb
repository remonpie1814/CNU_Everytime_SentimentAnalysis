# %%
import time
import konlpy
import openpyxl
import re
import pandas as pd
import requests
from konlpy.tag import Kkma
from selenium import webdriver
from selenium.webdriver import ActionChains
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver import Keys, ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import random

# %%
chrome_options = Options()
userAgent = UserAgent().random

chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
chrome_driver = "/usr/local/bin/chromedriver" # Your Chrome Driver path

driver = webdriver.Chrome(chrome_driver, options=chrome_options)

id = "blelakcat"
pw = "qwerty6*"

driver.get("https://everytime.kr")
time.sleep(1)


driver.find_element(By.XPATH,'/html/body/aside/div[1]/a[2]').click() # 로그인 이동 버튼
time.sleep(1)

driver.find_element(By.NAME, 'userid').send_keys(id) # 아이디
time.sleep(1)

driver.find_element(By.NAME, 'password').send_keys(pw) #비밀번호 
time.sleep(1)

driver.find_element(By.XPATH, '//*[@id="container"]/form/p[3]/input').click() # 로그인 확인 버튼 
time.sleep(3)

title_data = []
etime_data = []
content_data = []
vote_data = []
comment_data = []

def crawling(pg):
    soup = BeautifulSoup(pg,"html.parser")
    to_body = soup.find(class_="wrap articles")
    title = to_body.find_all("h2")
    etime = to_body.find_all("time") ############## 시간 추가
    content = to_body.find_all("p")
    vote = to_body.find_all(class_="vote")
    comment = to_body.find_all(class_="comment")

    for i in range(0,len(title)):
        title_data.append(title[i].text)
        etime_data.append(etime[i].text) ############### 시간 추가
        content_data.append(content[i].text)
        vote_data.append(vote[i].text)
        comment_data.append(comment[i].text)

    return title_data, etime_data, content_data, vote_data, comment_data

#첫 페이지 크롤링

driver.find_element(By.XPATH, '//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click() # 자유게시판 이동

time.sleep(2)

pg = driver.page_source

title, etime, content, vote, comment = crawling(pg)

print("1번째 페이지~")

page_num = 1                                                                        
while True:
    page_num += 1
    driver.find_element(By.CLASS_NAME, "next").click()
    time.sleep(random.uniform(2,4))
    title, etime, content, vote, comment = crawling(pg)
    #print("%d번째 페이지~"%(page_num_A))
    print("%d번째 페이지~"%(page_num))
    
    time.sleep(random.uniform(2,4))
    
    if page_num == 300 :
        time.sleep(20)
        print("첫번째 쉬는 시간")
    elif page_num == 600 :
        time.sleep(20)
        print("두 번째 쉬는 시간")
    elif page_num == 900 :
        time.sleep(20)
        print("세 번째 쉬는 시간")

    elif page_num > 999 :
        # 7 데이터프레임으로 변환 & 확인
        every_time_dict = {"title": title, "etime" : etime, "content": content, "vote": vote, "comment": comment}
        every_time_dataframe = pd.DataFrame(every_time_dict)
        display(every_time_dataframe)
        # 8 csv저장
        every_time_dataframe.to_csv('/Users/KBS/Documents/CNU_Everytime_SentimentAnalysis/kbs/data/data1~1000.csv', sep = '\t', index=False, header = True)
        time.sleep(2)
        driver.close()
        break
# Out:
# /Users/KBS/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#
# 846번째 페이지~
# 847번째 페이지~
# 848번째 페이지~
# 849번째 페이지~
# 850번째 페이지~
# 851번째 페이지~
# 852번째 페이지~
# 853번째 페이지~
# 854번째 페이지~
# 855번째 페이지~
# 856번째 페이지~
# 857번째 페이지~
# 858번째 페이지~
# 859번째 페이지~
# 860번째 페이지~
# 861번째 페이지~
# 862번째 페이지~
# 863번째 페이지~
# 864번째 페이지~
# 865번째 페이지~
# 866번째 페이지~
# 867번째 페이지~
# 868번째 페이지~
# 869번째 페이지~
# 870번째 페이지~
# 871번째 페이지~
# 872번째 페이지~
# 873번째 페이지~
# 874번째 페이지~
# 875번째 페이지~
# 876번째 페이지~
# 877번째 페이지~
# 878번째 페이지~
# 879번째 페이지~
# 880번째 페이지~
# 881번째 페이지~
# 882번째 페이지~
# 883번째 페이지~
# 884번째 페이지~
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/r8/hnw1hjlx54z7_g14njp906m00000gp/T/ipykernel_16594/573737831.py in <module>
#      65 while True:
#      66     page_num += 1
# ---> 67     driver.find_element(By.CLASS_NAME, "next").click()
#      68     time.sleep(random.uniform(2,4))
#      69     title, etime, content, vote, comment = crawling(pg)
#
# ~/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
# --> 858             'value': value})['value']
#     859
#     860     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     427         response = self.command_executor.execute(driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#     431                 response.get('value', None))
#
# ~/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".next"}
#   (Session info: chrome=106.0.5249.119)
# Stacktrace:
# 0   chromedriver                        0x000000010ad8c598 chromedriver + 4404632
# 1   chromedriver                        0x000000010ad13fa3 chromedriver + 3911587
# 2   chromedriver                        0x000000010a9c0e6a chromedriver + 425578
# 3   chromedriver                        0x000000010a9f8c91 chromedriver + 654481
# 4   chromedriver                        0x000000010a9f8e91 chromedriver + 654993
# 5   chromedriver                        0x000000010aa30274 chromedriver + 881268
# 6   chromedriver                        0x000000010aa16dcd chromedriver + 777677
# 7   chromedriver                        0x000000010aa2df79 chromedriver + 872313
# 8   chromedriver                        0x000000010aa16bd3 chromedriver + 777171
# 9   chromedriver                        0x000000010a9ebced chromedriver + 601325
# 10  chromedriver                        0x000000010a9ece51 chromedriver + 605777
# 11  chromedriver                        0x000000010ad5c0ce chromedriver + 4206798
# 12  chromedriver                        0x000000010ad60797 chromedriver + 4224919
# 13  chromedriver                        0x000000010ad67a4f chromedriver + 4254287
# 14  chromedriver                        0x000000010ad614da chromedriver + 4228314
# 15  chromedriver                        0x000000010ad3a23f chromedriver + 4067903
# 16  chromedriver                        0x000000010ad7e6a8 chromedriver + 4347560
# 17  chromedriver                        0x000000010ad7e816 chromedriver + 4347926
# 18  chromedriver                        0x000000010ad938fe chromedriver + 4434174
# 19  libsystem_pthread.dylib             0x00007ff80d9a04e1 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff80d99bf6b thread_start + 15

# %% [markdown]
# # except 추가

# %%
chrome_options = Options()
userAgent = UserAgent().random

chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
chrome_driver = "/usr/local/bin/chromedriver" # Your Chrome Driver path

driver = webdriver.Chrome(chrome_driver, options=chrome_options)

id = "blelakcat"
pw = "qwerty6*"

driver.get("https://everytime.kr")
time.sleep(1)


driver.find_element(By.XPATH,'/html/body/aside/div[1]/a[2]').click() # 로그인 이동 버튼
time.sleep(1)

driver.find_element(By.NAME, 'userid').send_keys(id) # 아이디
time.sleep(1)

driver.find_element(By.NAME, 'password').send_keys(pw) #비밀번호 
time.sleep(1)

driver.find_element(By.XPATH, '//*[@id="container"]/form/p[3]/input').click() # 로그인 확인 버튼 
time.sleep(3)

title_data = []
etime_data = []
content_data = []
vote_data = []
comment_data = []

def crawling(pg):
    soup = BeautifulSoup(pg,"html.parser")
    to_body = soup.find(class_="wrap articles")
    title = to_body.find_all("h2")
    etime = to_body.find_all("time") ############## 시간 추가
    content = to_body.find_all("p")
    vote = to_body.find_all(class_="vote")
    comment = to_body.find_all(class_="comment")

    for i in range(0,len(title)):
        title_data.append(title[i].text)
        etime_data.append(etime[i].text) ############### 시간 추가
        content_data.append(content[i].text)
        vote_data.append(vote[i].text)
        comment_data.append(comment[i].text)

    return title_data, etime_data, content_data, vote_data, comment_data

#첫 페이지 크롤링

driver.find_element(By.XPATH, '//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click() # 자유게시판 이동

time.sleep(2)

pg = driver.page_source

title, etime, content, vote, comment = crawling(pg)

print("1번째 페이지~")

page_num = 1                                                                        
while True:
    try:
        page_num += 1
        driver.find_element(By.CLASS_NAME, "next").click()
        time.sleep(random.uniform(2,4))
        title, etime, content, vote, comment = crawling(pg)
        #print("%d번째 페이지~"%(page_numA))
        print("%d번째 페이지~"%(page_num))

        time.sleep(random.uniform(2,4))

        if page_num % 3 == 0:
            time.sleep(20)

        elif page_num > 9 :
            # 7 데이터프레임으로 변환 & 확인
            every_time_dict = {"title": title, "etime" : etime, "content": content, "vote": vote, "comment": comment}
            every_time_dataframe = pd.DataFrame(every_time_dict)
            display(every_time_dataframe)
            # 8 csv저장
            every_time_dataframe.to_csv('/Users/KBS/Documents/CNU_Everytime_SentimentAnalysis/kbs/data/data1~1000.csv', sep = '\t', index=False, header = True)
            time.sleep(2)
            break
            
    except:

        if driver.find_element(By.CLASS_NAME, "next") != None:            

            time.sleep(10)                           

            pg = driver.page_source         

            title, etime, content, vote, comment = crawling(pg)

            print("%d번째 페이지~(오류가 있었지만 해결!)"%(i))

        else:

            print("%d번째 페이지는 없습니다~ 끝!"%(i))

            break
# Out:
# /Users/KBS/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   import sys
# 1번째 페이지~
# 2번째 페이지~
# 3번째 페이지~
# 4번째 페이지~
# 5번째 페이지~
# 6번째 페이지~

# %%
try:   
    driver.find_element_by_class_name("next").click()
    time.sleep(0.5)
        title, content, vote, comment = crawling(driver.page_source)
        print("[INFO] page %d completed ... "%page_num)

    except NoSuchElementException:
        try:
            time.sleep(3)
            driver.find_element_by_class_name("next").click()
            time.sleep(0.5)
            title, content, vote, comment = crawling(driver.page_source)
            printprint("[INFO] page %d completed ... "%page_num)
        except:
            print("[INFO] page %d is the last page. nice work!"%page_num)
            break
[출처] 에브리타임 - 크롤러 만들기(5) - 다듬기 및 완성|작성자 GanziDaeyong
